# %%
import pandas as pd
import numpy as np

rat_df = pd.read_csv('data/NYC_Rat_Sightings.csv')
RIR_df = pd.read_csv('data/NYC_Restaurant_Inspection_Results.csv')
print(rat_df.info())
print(RIR_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107049 entries, 0 to 107048
# Data columns (total 52 columns):
# Unique Key                        107049 non-null int64
# Created Date                      107049 non-null object
# Closed Date                       96129 non-null object
# Agency                            107049 non-null object
# Agency Name                       107049 non-null object
# Complaint Type                    107049 non-null object
# Descriptor                        107049 non-null object
# Location Type                     107043 non-null object
# Incident Zip                      106689 non-null float64
# Incident Address                  97583 non-null object
# Street Name                       97582 non-null object
# Cross Street 1                    88705 non-null object
# Cross Street 2                    88670 non-null object
# Intersection Street 1             9296 non-null object
# Intersection Street 2             9296 non-null object
# ...

# %%
rat_df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    31464015  09/04/2015 12:00:00 AM  09/18/2015 12:00:00 AM  DOHMH
# 1    31464024  09/04/2015 12:00:00 AM  10/28/2015 12:00:00 AM  DOHMH
# 2    31464025  09/04/2015 12:00:00 AM                     NaN  DOHMH
# 3    31464026  09/04/2015 12:00:00 AM  09/14/2015 12:00:00 AM  DOHMH
# 4    31464027  09/04/2015 12:00:00 AM  09/22/2015 12:00:00 AM  DOHMH
#
#                                Agency Name Complaint Type    Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#                   Location Type  Incident Zip      Incident Address  \
# ...

# %%
RIR_df.head()
# Out:
#       CAMIS                  DBA           BORO BUILDING           STREET  \
# 0  41658103            CHOP SHOP      MANHATTAN      254        10 AVENUE
# 1  41261148  EL VALLE RESTAURANT          BRONX      640   MELROSE AVENUE
# 2  40389807        CHAMP GOURMET      MANHATTAN       30     BROAD STREET
# 3  41574708    PRONTO RESTAURANT  STATEN ISLAND     3297  RICHMOND AVENUE
# 4  50064814           PURE GREEN      MANHATTAN       60         E 8TH ST
#
#    ZIPCODE       PHONE                                CUISINE DESCRIPTION  \
# 0  10001.0  2128200333                                              Asian
# 1  10455.0  7185855858  Latin (Cuban, Dominican, Puerto Rican, South &...
# 2  10004.0  2123634000                                           American
# 3  10312.0  7183562442                                      Pizza/Italian
# 4  10003.0  2125290081                     Juice, Smoothies, Fruit Salads
#
#   INSPECTION DATE                                           ACTION  \
# ...
